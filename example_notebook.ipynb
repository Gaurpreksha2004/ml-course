# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
#  ## sample project
#  you can put description text or some text related to your project

# %%
import pandas as pd

# %%
df = pd.read_csv("heart.csv")

# %% [markdown]
# The following table shows heart disease information

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %% [markdown]
# ## df.col_name.value_counts().plot(kind='bar')
# -- > format for creating the graph(here bar graph) for a column by counting its value
#
# the target column has two values ->  0s and 1s

# %%
df.target.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='target'>

# %% [markdown]
# This the markdown code for'import this image to notebook'  ->  !square_brackets(image_name.extension)

# %% [markdown]
# ![](download.jpeg)

# %% [markdown]
# ## 1. Problem Defination
# Predict Heart Disease

# %% [markdown]
# ## 2. Data
# This the data we are using

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo\\Desktop\\sample_project_1'

# %%
# !dir # exclamation mark tells that we are treating the command as if we are running it on the terminal
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 12C7-369C
#
#  Directory of C:\Users\Lenovo\Desktop\sample_project_1
#
# 07/30/2025  02:56 PM    <DIR>          .
# 07/24/2025  04:14 PM    <DIR>          ..
# 07/30/2025  02:24 PM    <DIR>          .ipynb_checkpoints
# 07/30/2025  02:23 PM             6,030 download.jpeg
# 07/24/2025  04:29 PM    <DIR>          env
# 07/30/2025  02:56 PM            23,325 example_notebook.ipynb
# 07/30/2025  02:07 PM            38,114 heart.csv
#                3 File(s)         67,469 bytes
#                4 Dir(s)  31,354,093,568 bytes free
